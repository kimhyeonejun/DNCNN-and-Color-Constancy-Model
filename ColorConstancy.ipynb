# %% [markdown]
# #Network 구성

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import torch.nn as nn
import torch.optim as optim
from torchvision.transforms import *
import torch
import math
from os.path import join
import torch.utils.data as data
import numpy as np
from os import listdir
from os.path import join
from PIL import Image, ImageOps
import random
from random import randrange
from math import sqrt



class FC4(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(FC4, self).__init__()

        self.layer1 = nn.Conv2d(in_channels=in_ch, out_channels=96, kernel_size=11, stride=4, padding=5, bias=False)
        self.layer2 = nn.Conv2d(in_channels=96, out_channels=256, kernel_size=5, stride=1, padding=2, bias=False)
        self.layer3 = nn.Conv2d(in_channels=256, out_channels=384, kernel_size=5, stride=1, padding=2, bias=False)
        self.layer4 = nn.Conv2d(in_channels=384, out_channels=384, kernel_size=5, stride=1, padding=2, bias=False)
        self.layer5 = nn.Conv2d(in_channels=384, out_channels=256, kernel_size=5, stride=1, padding=2, bias=False)
        self.layer6 = nn.Conv2d(in_channels=256, out_channels=128, kernel_size=3, stride=1, padding=1, bias=False)
        self.layer7 = nn.Conv2d(in_channels=128, out_channels=out_ch, kernel_size=3, stride=1, padding=1, bias=False)
        self.Maxpooling = nn.MaxPool2d(kernel_size=2, stride=2)
        self.relu = nn.ReLU(inplace=True)
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):

        x = self.relu(self.layer1(x))
        x = self.Maxpooling(x)
        x = self.relu(self.layer2(x))
        x = self.Maxpooling(x)
        x = self.relu(self.layer3(x))
        x = self.relu(self.layer4(x))
        x = self.relu(self.layer5(x))
        x = self.Maxpooling(x)
        out = self.relu(self.layer6(x))
        # out = self.dropout(out)
        out = abs(self.layer7(out))

        local_illum =out[:,:3,:,:]
        conf = out[:,3:4,:,:]

        conf_map_re = torch.reshape(conf, [conf.size(0), conf.size(2) * conf.size(3)])
        sum = torch.sum(conf_map_re, dim=1)
        sum = sum.reshape([sum.size(0), 1, 1, 1])
        conf = conf / (sum.repeat([1, 1, conf.size(2), conf.size(3)]) + 0.00001)
        conf_map = conf.repeat([1, 3, 1, 1])

        normal = (torch.norm(local_illum[:, :, :, :], p=2, dim=1, keepdim=True) + 1e-04)
        local_illum = local_illum[:, :, :, :] / normal

        local_il = local_illum * conf_map
        local_il = local_il.reshape(local_il.size(0), local_il.size(1), local_il.size(2) * local_il.size(3))
        weighted_sum = torch.sum(local_il, dim=2)
        pred = weighted_sum / (torch.norm(weighted_sum, dim=1, p=2, keepdim=True) + 0.000001)

        return pred

# %% [markdown]
# #Dataset 구성

# %%
import os
import torch
import torch.utils.data as data
import numpy as np
from os import listdir
from os.path import join
from PIL import Image
import random
import scipy
from scipy import io


def is_image_file(filename):
    return any(filename.endswith(extension) for extension in [".png", ".jpg", ".jpeg",".bmp"])

def is_mat_file(filename):
    return any(filename.endswith(extension) for extension in [".mat"])

def is_txt_file(filename):
    return any(filename.endswith(extension) for extension in [".txt"])


def load_img(filepath):
    img = Image.open(filepath).convert('RGB')
    return img

def get_patch_2tensor(img_in,wb_img_in, patch_size=256): # img_in : 이미지 파일 w,h | wb_img_in : 텐서 c,h,w
    c ,ih, iw = img_in.size()
    ip = patch_size

    ix = random.randrange(0, iw - ip + 1)
    iy = random.randrange(0, ih - ip + 1)

    img_in = img_in[:,iy:iy+ip,ix:ix+ip]
    wb_img_in = wb_img_in[:,iy:iy+ip,ix:ix+ip]

    return img_in,wb_img_in

class DatasetFromFolder(data.Dataset):
    def __init__(self, image_dir, folder, isTrain, transform=None):
        super(DatasetFromFolder, self).__init__()

        self.Train = isTrain
        self.istrain = folder

        self.im_dir = os.path.join(image_dir, self.istrain, 'rgb/')
        self.wb_im_dir = os.path.join(image_dir, self.istrain, 'wb_rgb/')
        self.gt_label_dir = os.path.join(image_dir, self.istrain, 'label/')

        self.image_filenames = [join(self.im_dir, x) for x in os.listdir(self.im_dir) if is_image_file(x)]
        self.wb_image_filenames = [join(self.wb_im_dir, x) for x in os.listdir(self.wb_im_dir) if is_image_file(x)]
        self.gt_label_filenames = [join(self.gt_label_dir, x) for x in os.listdir(self.gt_label_dir) if is_txt_file(x)]

        self.transform = transform

    def __getitem__(self, index):

        input_im = load_img(self.image_filenames[index])
        wb_input_im = load_img(self.wb_image_filenames[index])
        gt_label = np.zeros(shape=(3))

        with open(self.gt_label_filenames[index]) as f:
            lines = f.readlines()[0:3]
        for i in range(3):
            gt_label[i] = float(lines[i])  # 형 변환 추가

        gt_label = torch.from_numpy(gt_label)


        if self.Train == True:
            if self.transform:
                rgb = self.transform(input_im)
                wb_rgb = self.transform(wb_input_im)
            return rgb, wb_rgb, gt_label
        else:
            _, file = os.path.split(self.image_filenames[index])
            if self.transform:
                rgb = self.transform(input_im)
                wb_rgb = self.transform(wb_input_im)

            return rgb, wb_rgb, gt_label, file

    def __len__(self):
        return len(self.image_filenames)

# %% [markdown]
# #Training

# %%
from __future__ import print_function
import argparse
from math import log10

import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.autograd import Variable
from torch.utils.data import DataLoader
import pdb
import socket
import time
import easydict

opt = easydict.EasyDict({
    "batchSize": 8,           # batch size - 한번에 training할 patch의 숫자
    "lr": 1e-4,                # learning rate
    "start_iter": 1,
    "nEpochs": 100,            # training 횟수
    "data_dir":"/content/drive/MyDrive/Colab Notebooks/dataset/", # dataset 저장 위치
    "model_type": "FC4",         # 모델이름
    "save_folder": "/content/drive/MyDrive/Colab Notebooks/weight/", # weight 저장 위치
    "pretrained_sr": "/content/drive/MyDrive/Colab Notebooks/weight/epoch_200.pth",
    "pretrained": False,
    "gpu_mode": True,
    "threads": 1,
    "seed": 123,
    "gpus": 1})

# gpus_list = range(opt.gpus)
device = "cuda:0"
hostname = str(socket.gethostname())
cudnn.benchmark = True
print(opt)

if not os.path.exists(opt.save_folder):
    os.makedirs(opt.save_folder)

def train(epoch):
    epoch_loss = 0
    model.train()
    for iteration, batch in enumerate(training_data_loader, 1):
        rgb, wb_rgb, gt_label = Variable(batch[0]), Variable(batch[1]), Variable(batch[2])
        if cuda:
            rgb = rgb.cuda()
            wb_rgb = wb_rgb.cuda()
            gt_label = gt_label.cuda()

        optimizer.zero_grad()
        t0 = time.time()
        pred = model(rgb)


        loss = angular_loss(pred, gt_label)
        t1 = time.time()
        epoch_loss += loss.data
        loss.backward()
        optimizer.step()

        print("===> Epoch[{}]({}/{}): Loss: {:.4f} || Timer: {:.4f} sec.".format(epoch, iteration, len(training_data_loader), loss.data, (t1 - t0)))

    print("===> Epoch {} Complete: Avg. Loss: {:.4f}".format(epoch, epoch_loss / len(training_data_loader)))


def eval(epoch):
    angular_list=[]
    avg_cc = 0
    model.eval()
    for i,batch in enumerate(testing_data_loader):
        with torch.no_grad():
            rgb,wb_rgb,gt_label = Variable(batch[0]), Variable(batch[1]), Variable(batch[2])

        if cuda:
            rgb = rgb.cuda()
            wb_rgb = wb_rgb.cuda()
            gt_label = gt_label.cuda()

        with torch.no_grad():
            pred = model(rgb)

        ''' calculate AE '''
        cc = angular_loss(pred, gt_label)

        avg_cc += cc
        angular_list.append(cc)
        print('{}번째 angular error = {:.4f}'.format(i, cc))
    angular_list1 = angular_list.copy()
    index_min = []
    index_max = []
    '''AE measure'''
    angular_list.sort()
    onefourth = len(testing_data_loader) // 4
    median = angular_list[len(testing_data_loader) // 2]
    maxerror, minerror = 0, 0
    # min 25% error
    for i in range(onefourth):
        minerror += angular_list[i]
        index_min.append(angular_list1.index(angular_list[i]))
    # max 25% error
    angular_list.sort(reverse=True)
    for i in range(onefourth):
        maxerror += angular_list[i]
        index_max.append(angular_list1.index(angular_list[i]))

    maxerror = maxerror / onefourth
    minerror = minerror / onefourth
    avg_cc = avg_cc / len(testing_data_loader)
    print('average:{:.4f} | median:{:.4f} | worst:{:.4f} | Best:{:.4f}'.format(avg_cc,median,maxerror,minerror))
    print("===> Processing Done")
    log('Epoch[{:.4f}] : average = {:.4f}| median:{:.4f} | worst:{:.4f} | Best:{:.4f}\n'.format(epoch,avg_cc,median,maxerror,minerror) , logfile)

def log(text, LOGGER_FILE):
    with open(LOGGER_FILE, 'a') as f:
        f.write(text)
        f.close()

def angular_loss(pred, gt):
    pred.cuda()
    gt.cuda()
    a = (pred[:, 0] * gt[:, 0] + pred[:, 1] * gt[:, 1] + pred[:, 2] * gt[:, 2])
    b = pow(torch.abs(pred[:, 0] * pred[:, 0] + pred[:, 1] * pred[:, 1] + pred[:, 2] * pred[:, 2] + 1e-06), 1 / 2)
    c = pow(torch.abs(gt[:, 0] * gt[:, 0] + gt[:, 1] * gt[:, 1] + gt[:, 2] * gt[:, 2] + 1e-06), 1 / 2)

    acos = torch.acos(a / (b * c + 1e-05))
    output = torch.mean(acos)
    output = output * 180 / math.pi

    return output

def print_network(net):
    num_params = 0
    for param in net.parameters():
        num_params += param.numel()
    print(net)
    print('Total number of parameters: %d' % num_params)

def checkpoint(epoch):
    model_out_path = opt.save_folder+"epoch_{}.pth".format(epoch)
    torch.save(model.state_dict(), model_out_path)
    print("Checkpoint saved to {}".format(model_out_path))

def transform():
    return Compose([
        ToTensor(),
    ])

if __name__ == '__main__':

    cuda = opt.gpu_mode
    if cuda and not torch.cuda.is_available():
        raise Exception("No GPU found, please run without --cuda")

    torch.manual_seed(opt.seed)
    if cuda:
        torch.cuda.manual_seed(opt.seed)

    print('===> Loading datasets')

    train_set = DatasetFromFolder(image_dir = opt.data_dir, folder = "train/" , isTrain = True, transform = transform())
    training_data_loader = DataLoader(dataset=train_set, num_workers=opt.threads, batch_size=opt.batchSize, shuffle=True)
    test_set = DatasetFromFolder(image_dir = opt.data_dir, folder = "test/" , isTrain = False, transform = transform())
    testing_data_loader = DataLoader(dataset=test_set, num_workers=opt.threads, batch_size=opt.batchSize, shuffle=False)

    print('===> Building model ', opt.model_type)
    model = FC4(in_ch=3,out_ch=4)

    model = torch.nn.DataParallel(model, device_ids=[0])

    if opt.pretrained:
        model_name = os.path.join(opt.save_folder + opt.pretrained_sr)
        if os.path.exists(model_name):
            model.load_state_dict(torch.load(model_name, map_location=lambda storage, loc: storage))
            print('Pre-trained FC4 model is loaded.')

    if cuda:
        model = model.cuda()

    optimizer = optim.Adam(model.parameters(), lr=opt.lr, betas=(0.9, 0.999), eps=1e-8, weight_decay=1e-4)
    logfile = opt.save_folder + 'eval.txt'
    for epoch in range(opt.start_iter, opt.nEpochs + 1):

        train(epoch)

        if (epoch) % 10 == 0:
            checkpoint(epoch)
            eval(epoch)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ===> Epoch[4](90/145): Loss: 7.7972 || Timer: 0.0103 sec.
# ===> Epoch[4](91/145): Loss: 11.6094 || Timer: 0.0053 sec.
# ===> Epoch[4](92/145): Loss: 5.9526 || Timer: 0.0068 sec.
# ===> Epoch[4](93/145): Loss: 7.2882 || Timer: 0.0220 sec.
# ===> Epoch[4](94/145): Loss: 5.9069 || Timer: 0.0110 sec.
# ===> Epoch[4](95/145): Loss: 7.7949 || Timer: 0.0089 sec.
# ===> Epoch[4](96/145): Loss: 5.3341 || Timer: 0.0034 sec.
# ===> Epoch[4](97/145): Loss: 9.9203 || Timer: 0.0101 sec.
# ===> Epoch[4](98/145): Loss: 10.9826 || Timer: 0.0041 sec.
# ===> Epoch[4](99/145): Loss: 7.2795 || Timer: 0.0036 sec.
# ===> Epoch[4](100/145): Loss: 9.9631 || Timer: 0.0048 sec.
# ===> Epoch[4](101/145): Loss: 8.1268 || Timer: 0.0032 sec.
# ===> Epoch[4](102/145): Loss: 4.7264 || Timer: 0.0038 sec.
# ===> Epoch[4](103/145): Loss: 5.6482 || Timer: 0.0046 sec.
# ===> Epoch[4](104/145): Loss: 5.0151 || Timer: 0.0034 sec.
# ===> Epoch[4](105/145): Loss: 3.7454 || Timer: 0.0037 sec.
# ===> Epoch[4](106/145): Loss: 5.2281 || Timer: 0.0032 sec.
# ===> Epoch[4](107/145): Loss: 8.6554 || Timer: 0.0035 sec.
# ===> Epoch[4](108/145): Loss: 6.0155 || Timer: 0.0033 sec.
# ===> Epoch[4](109/145): Loss: 5.2776 || Timer: 0.0036 sec.
# ===> Epoch[4](110/145): Loss: 4.8627 || Timer: 0.0047 sec.
# ===> Epoch[4](111/145): Loss: 5.9922 || Timer: 0.0033 sec.
# ===> Epoch[4](112/145): Loss: 4.8726 || Timer: 0.0035 sec.
# ===> Epoch[4](113/145): Loss: 5.0467 || Timer: 0.0042 sec.
# ===> Epoch[4](114/145): Loss: 6.1976 || Timer: 0.0036 sec.
# ===> Epoch[4](115/145): Loss: 13.8493 || Timer: 0.0033 sec.
# 18번째 angular error = 4.1240
# 19번째 angular error = 13.9456
# 20번째 angular error = 29.6513
# 21번째 angular error = 2.1970
# 22번째 angular error = 2.9128
# 23번째 angular error = 1.9339
# 24번째 angular error = 2.9785
# 25번째 angular error = 17.9498
# 26번째 angular error = 13.4252
# 27번째 angular error = 1.7062
# 28번째 angular error = 4.2063
# 29번째 angular error = 2.9873
# 30번째 angular error = 4.8481
# 31번째 angular error = 4.5079
# 32번째 angular error = 12.1715
# 33번째 angular error = 9.4819
# 34번째 angular error = 4.7926
# 35번째 angular error = 1.8467
# 36번째 angular error = 3.3287
# 37번째 angular error = 2.9301
# 38번째 angular error = 3.9675
# 39번째 angular error = 3.4310
# 40번째 angular error = 2.3466
# 41번째 angular error = 1.4144
# 42번째 angular error = 3.1977
# 43번째 angular error = 3.7832
# 44번째 angular error = 2.0203
# 45번째 angular error = 2.6522
# 46번째 angular error = 8.3733
# 47번째 angular error = 1.6451
# 48번째 angular error = 16.6338
# 49번째 angular error = 23.2386
# 50번째 angular error = 1.5266
# 51번째 angular error = 4.1936
# 52번째 angular error = 5.6638
# 53번째 angular error = 22.5619
# 54번째 angular error = 3.7664
# 55번째 angular error = 3.0010
# 56번째 angular error = 21.6704
# 57번째 angular error = 16.3642
# 58번째 angular error = 4.1271
# 59번째 angular error = 1.2765
# 60번째 angular error = 2.2244
# 61번째 angular error = 19.1488
# 62번째 angular error = 3.9036
# 63번째 angular error = 22.6214
# 64번째 angular error = 4.2038
# 65번째 angular error = 0.3609
# 66번째 angular error = 18.5526
# 67번째 angular error = 3.6837
# 68번째 angular error = 1.8072
# 69번째 angular error = 14.2640
# 70번째 angular error = 2.0952
# 71번째 angular error = 2.3090
# 72번째 angular error = 4.8266
# 73번째 angular error = 3.8410
# 74번째 angular error = 2.0598
# 75번째 angular error = 14.0801
# 76번째 angular error = 26.7380
# 77번째 angular error = 2.6602
# 78번째 angular error = 3.8854
# 79번째 angular error = 17.8362
# 80번째 angular error = 1.7753
# 81번째 angular error = 3.7535
# 82번째 angular error = 3.6220
# 83번째 angular error = 3.2985
# 84번째 angular error = 2.6307
# 85번째 angular error = 2.4956
# 86번째 angular error = 18.9639
# 87번째 angular error = 1.3456
# 88번째 angular error = 4.3246
# 89번째 angular error = 3.5355
# 90번째 angular error = 3.4304
# 91번째 angular error = 3.5680
# 92번째 angular error = 4.9677
# 93번째 angular error = 4.2326
# 94번째 angular error = 2.4895
# 95번째 angular error = 4.4328
# 96번째 angular error = 2.9799
# 97번째 angular error = 18.0268
# 98번째 angular error = 2.8452
# 99번째 angular error = 1.6143
# 100번째 angular error = 4.3037
# 101번째 angular error = 3.1624
# 102번째 angular error = 1.4227
# 103번째 angular error = 21.9796
# 104번째 angular error = 2.6584
# 105번째 angular error = 1.6268
# 106번째 angular error = 4.3462
# 107번째 angular error = 6.2005
# 108번째 angular error = 2.6024
# 109번째 angular error = 3.2193
# 110번째 angular error = 3.3317
# 111번째 angular error = 0.9994
# 112번째 angular error = 7.0925
# 113번째 angular error = 6.6368
# 114번째 angular error = 3.4693
# 115번째 angular error = 2.7724
# 116번째 angular error = 3.0408
# 117번째 angular error = 21.4554
# 118번째 angular error = 4.1400
# 119번째 angular error = 6.3747
# 120번째 angular error = 18.7286
# 121번째 angular error = 3.6334
# 122번째 angular error = 2.0409
# 123번째 angular error = 8.4532
# 124번째 angular error = 2.3794
# 125번째 angular error = 2.0875
# 126번째 angular error = 7.0584
# 127번째 angular error = 6.2599
# 128번째 angular error = 7.1617
# 129번째 angular error = 14.6291
# 130번째 angular error = 3.3787
# 131번째 angular error = 10.1159
# 132번째 angular error = 4.2088
# 133번째 angular error = 2.7572
# 134번째 angular error = 2.7512
# 135번째 angular error = 4.0571
# 136번째 angular error = 4.1826
# 137번째 angular error = 4.5179
# 138번째 angular error = 5.8905
# 139번째 angular error = 6.4367
# 140번째 angular error = 21.3966
# 141번째 angular error = 3.7859
# 142번째 angular error = 2.6390
# 143번째 angular error = 8.4451
# 144번째 angular error = 2.9940
# 145번째 angular error = 5.1409
# 146번째 angular error = 23.5678
# 147번째 angular error = 2.7510
# 148번째 angular error = 2.4012
# 149번째 angular error = 27.2072
# 150번째 angular error = 4.3997
# 151번째 angular error = 17.4251
# 152번째 angular error = 3.9113
# 153번째 angular error = 3.3018
# 154번째 angular error = 5.5643
# 155번째 angular error = 1.4281
# 156번째 angular error = 3.2652
# 157번째 angular error = 2.1212
# 158번째 angular error = 1.8799
# 159번째 angular error = 1.6980
# 160번째 angular error = 2.4688
# 161번째 angular error = 2.1975
# 162번째 angular error = 3.4936
# 163번째 angular error = 2.4010
# 164번째 angular error = 19.5427
# 165번째 angular error = 1.4088
# 166번째 angular error = 7.3270
# 167번째 angular error = 13.1955
# 168번째 angular error = 3.6506
# 169번째 angular error = 3.9276
# 170번째 angular error = 2.9691
# 171번째 angular error = 3.0992
# 172번째 angular error = 25.6170
# 173번째 angular error = 6.7863
# 174번째 angular error = 4.9509
# 175번째 angular error = 16.8269
# 176번째 angular error = 19.1054
# 177번째 angular error = 2.0553
# 178번째 angular error = 1.1520
# 179번째 angular error = 3.5940
# 180번째 angular error = 19.4141
# 181번째 angular error = 7.3219
# 182번째 angular error = 4.8687
# 183번째 angular error = 1.8070
# 184번째 angular error = 2.7809
# 185번째 angular error = 2.3764
# 186번째 angular error = 3.3802
# 187번째 angular error = 18.4155
# 188번째 angular error = 2.2157
# 189번째 angular error = 1.7957
# 190번째 angular error = 3.0768
# 191번째 angular error = 7.7435
# 192번째 angular error = 4.3310
# 193번째 angular error = 2.7364
# 194번째 angular error = 5.4510
# 195번째 angular error = 2.6161
# 196번째 angular error = 10.1628
# 197번째 angular error = 5.7458
# 198번째 angular error = 2.9504
# 199번째 angular error = 2.3766
# 200번째 angular error = 7.9074
# 201번째 angular error = 4.9397
# 202번째 angular error = 4.8625
# 203번째 angular error = 5.7879
# 204번째 angular error = 5.6694
# 205번째 angular error = 5.5387
# 206번째 angular error = 10.3935
# 207번째 angular error = 5.3173
# 208번째 angular error = 8.4241
# 209번째 angular error = 4.8584
# 210번째 angular error = 7.1863
# 211번째 angular error = 5.8924
# 212번째 angular error = 5.3932
# 310번째 angular error = 2.9106
# 311번째 angular error = 22.0831
# 312번째 angular error = 3.9735
# 313번째 angular error = 5.5131
# 314번째 angular error = 3.5050
# 315번째 angular error = 1.5695
# 316번째 angular error = 4.6923
# 317번째 angular error = 3.3765
# 318번째 angular error = 2.7302
# 319번째 angular error = 3.0944
# 320번째 angular error = 2.4782
# 321번째 angular error = 2.4199
# 322번째 angular error = 5.3356
# 323번째 angular error = 3.9549
# 324번째 angular error = 6.2706
# 325번째 angular error = 19.0106
# 326번째 angular error = 15.0511
# 327번째 angular error = 6.2396
# 328번째 angular error = 2.6734
# 329번째 angular error = 5.0043
# 330번째 angular error = 5.2728
# 331번째 angular error = 2.9489
# 332번째 angular error = 1.2848
# 333번째 angular error = 2.0421
# 334번째 angular error = 1.4461
# 335번째 angular error = 21.5066
# 336번째 angular error = 4.6334
# 337번째 angular error = 22.2228
# 338번째 angular error = 4.4190
# 339번째 angular error = 4.5135
# 340번째 angular error = 19.2363
# 341번째 angular error = 6.7209
# 342번째 angular error = 3.0053
# 343번째 angular error = 2.0909
# 344번째 angular error = 13.6999
# 345번째 angular error = 2.1024
# 346번째 angular error = 2.3380
# 347번째 angular error = 2.7959
# 348번째 angular error = 22.9161
# 349번째 angular error = 3.2716
# 350번째 angular error = 2.5875
# 351번째 angular error = 1.9177
# 352번째 angular error = 1.6296
# 353번째 angular error = 3.9005
# 354번째 angular error = 4.0951
# 355번째 angular error = 5.7922
# 356번째 angular error = 3.5147
# 357번째 angular error = 0.5886
# 358번째 angular error = 2.0797
# 359번째 angular error = 7.0940
# 360번째 angular error = 0.8800
# 361번째 angular error = 0.9056
# 362번째 angular error = 3.2081
# 363번째 angular error = 2.8732
# 364번째 angular error = 2.7435
# 365번째 angular error = 2.7826
# 366번째 angular error = 2.3422
# 367번째 angular error = 21.5527
# 368번째 angular error = 0.9062
# 369번째 angular error = 1.7246
# 370번째 angular error = 19.1085
# 371번째 angular error = 7.9422
# 372번째 angular error = 2.3467
# 373번째 angular error = 2.3126
# 374번째 angular error = 1.8733
# 375번째 angular error = 1.3666
# 376번째 angular error = 0.5013
# 377번째 angular error = 4.9163
# 378번째 angular error = 1.3527
# 379번째 angular error = 1.0957
# 380번째 angular error = 0.9098
# 381번째 angular error = 0.7138
# 382번째 angular error = 15.8118
# 383번째 angular error = 1.6840
# 384번째 angular error = 2.1900
# 385번째 angular error = 2.8820
# 386번째 angular error = 11.9297
# 387번째 angular error = 24.9860
# 388번째 angular error = 4.6266
# 389번째 angular error = 24.9409
# 390번째 angular error = 9.2278
# 391번째 angular error = 3.2119
# 392번째 angular error = 2.9800
# 393번째 angular error = 6.5549
# 394번째 angular error = 28.6159
# 395번째 angular error = 0.4905
# 396번째 angular error = 2.3727
# 397번째 angular error = 3.4057
# 398번째 angular error = 1.7217
# 399번째 angular error = 3.4115
# 400번째 angular error = 25.7770
# 401번째 angular error = 17.8938
# 402번째 angular error = 1.9691
# 403번째 angular error = 8.9018
# 404번째 angular error = 2.1495
# 405번째 angular error = 3.1801
# 406번째 angular error = 2.0927
# 504번째 angular error = 23.5148
# 505번째 angular error = 3.3255
# 506번째 angular error = 3.6931
# 507번째 angular error = 13.3360
# 508번째 angular error = 27.0762
# 509번째 angular error = 11.4388
# 510번째 angular error = 7.2299
# 511번째 angular error = 4.9950
# 512번째 angular error = 5.1731
# 513번째 angular error = 1.4606
# 514번째 angular error = 25.3733
# 515번째 angular error = 3.2479
# 516번째 angular error = 2.9420
# 517번째 angular error = 4.7752
# 518번째 angular error = 5.5617
# 519번째 angular error = 7.0226
# 520번째 angular error = 3.7080
# 521번째 angular error = 3.0518
# 522번째 angular error = 4.0494
# 523번째 angular error = 20.9636
# 524번째 angular error = 7.0168
# 525번째 angular error = 24.4308
# 526번째 angular error = 3.3257
# 527번째 angular error = 6.4666
# 528번째 angular error = 5.9705
# 529번째 angular error = 26.0105
# 530번째 angular error = 3.6229
# 531번째 angular error = 3.7748
# 532번째 angular error = 8.8015
# 533번째 angular error = 4.7274
# 534번째 angular error = 1.8794
# 535번째 angular error = 2.7778
# 536번째 angular error = 4.5146
# 537번째 angular error = 4.0734
# 538번째 angular error = 4.4060
# 539번째 angular error = 9.2010
# 540번째 angular error = 1.0275
# 541번째 angular error = 12.0493
# 542번째 angular error = 4.2505
# 543번째 angular error = 3.0979
# 544번째 angular error = 1.1499
# 545번째 angular error = 2.0141
# 546번째 angular error = 23.8233
# 547번째 angular error = 24.2718
# 548번째 angular error = 10.1429
# 549번째 angular error = 9.3394
# 550번째 angular error = 2.3974
# 551번째 angular error = 3.1941
# 552번째 angular error = 3.4016
# 553번째 angular error = 3.8326
# 554번째 angular error = 24.0789
# 555번째 angular error = 3.4421
# 556번째 angular error = 19.5214
# 557번째 angular error = 3.0456
# 558번째 angular error = 20.5899
# 559번째 angular error = 2.9409
# 560번째 angular error = 4.0815
# 561번째 angular error = 13.1315
# 562번째 angular error = 5.3322
# 563번째 angular error = 20.8058
# 564번째 angular error = 2.3195
# 565번째 angular error = 1.5445
# 566번째 angular error = 0.9793
# 567번째 angular error = 3.1238
# 568번째 angular error = 3.4224
# 569번째 angular error = 19.1763
# 570번째 angular error = 3.3453
# 571번째 angular error = 21.2626
# 572번째 angular error = 7.9323
# 573번째 angular error = 22.8085
# 574번째 angular error = 18.3268
# 575번째 angular error = 19.6386
# 576번째 angular error = 22.1528
# 577번째 angular error = 2.8601
# average:6.8641 | median:4.1936 | worst:16.7016 | Best:1.8655
# ===> Processing Done
# ===> Epoch[5](1/145): Loss: 8.0945 || Timer: 0.0063 sec.
# ===> Epoch[5](2/145): Loss: 3.2121 || Timer: 0.0045 sec.
# ===> Epoch[5](3/145): Loss: 7.7123 || Timer: 0.0032 sec.
# ===> Epoch[5](4/145): Loss: 7.2487 || Timer: 0.0033 sec.
# ===> Epoch[5](5/145): Loss: 5.2693 || Timer: 0.0038 sec.
# ===> Epoch[5](6/145): Loss: 5.4560 || Timer: 0.0097 sec.
# ===> Epoch[5](7/145): Loss: 12.6122 || Timer: 0.0044 sec.
# ===> Epoch[5](8/145): Loss: 6.5953 || Timer: 0.0035 sec.
# ===> Epoch[5](126/145): Loss: 4.9675 || Timer: 0.0035 sec.
# ===> Epoch[5](127/145): Loss: 5.1420 || Timer: 0.0035 sec.
# ===> Epoch[5](128/145): Loss: 3.2750 || Timer: 0.0053 sec.
# ===> Epoch[5](129/145): Loss: 7.6271 || Timer: 0.0042 sec.
# ===> Epoch[5](130/145): Loss: 8.1213 || Timer: 0.0037 sec.
# ===> Epoch[5](131/145): Loss: 3.1502 || Timer: 0.0039 sec.
# ===> Epoch[5](132/145): Loss: 11.5700 || Timer: 0.0040 sec.
# ===> Epoch[5](133/145): Loss: 10.8073 || Timer: 0.0099 sec.
# ===> Epoch[5](134/145): Loss: 10.1376 || Timer: 0.0034 sec.
# ===> Epoch[5](135/145): Loss: 8.0283 || Timer: 0.0040 sec.
# ===> Epoch[5](136/145): Loss: 3.7560 || Timer: 0.0036 sec.
# ===> Epoch[5](137/145): Loss: 10.0493 || Timer: 0.0053 sec.
# ===> Epoch[5](138/145): Loss: 8.2930 || Timer: 0.0037 sec.
# ===> Epoch[5](139/145): Loss: 5.6966 || Timer: 0.0033 sec.
# ===> Epoch[5](140/145): Loss: 7.2698 || Timer: 0.0032 sec.
# ===> Epoch[5](141/145): Loss: 6.6933 || Timer: 0.0042 sec.
# ===> Epoch[5](142/145): Loss: 10.0349 || Timer: 0.0033 sec.
# ===> Epoch[5](143/145): Loss: 5.2677 || Timer: 0.0033 sec.
# ===> Epoch[5](144/145): Loss: 6.5152 || Timer: 0.0034 sec.
# ===> Epoch[5](145/145): Loss: 5.7264 || Timer: 0.0028 sec.
# ===> Epoch 5 Complete: Avg. Loss: 6.7029
# Checkpoint saved to /content/drive/MyDrive/weights/cc/epoch_5.pth
# 0번째 angular error = 2.0643
# 1번째 angular error = 1.6589
# 2번째 angular error = 2.9873
# 3번째 angular error = 0.7735
# 4번째 angular error = 11.0228
# 5번째 angular error = 6.7196
# 6번째 angular error = 1.9598
# 7번째 angular error = 1.2416
# 8번째 angular error = 6.4401
# 9번째 angular error = 0.4593
# 10번째 angular error = 1.0607
# 11번째 angular error = 2.9780
# 12번째 angular error = 5.2348
# 13번째 angular error = 1.8753
# 14번째 angular error = 3.3291
# 15번째 angular error = 21.9919
# 16번째 angular error = 3.2893
# 17번째 angular error = 3.4586
# 18번째 angular error = 3.8262
# 19번째 angular error = 14.4297
# 20번째 angular error = 30.1437
# 21번째 angular error = 1.9276
# 22번째 angular error = 2.7653
# 23번째 angular error = 1.9252
# 24번째 angular error = 2.9124
# 25번째 angular error = 18.4204
# 26번째 angular error = 13.8114
# 27번째 angular error = 1.5610
# 28번째 angular error = 4.5648
# 29번째 angular error = 2.7420
# 30번째 angular error = 4.5921
# 31번째 angular error = 4.2915
# 32번째 angular error = 12.5325
# 33번째 angular error = 9.1851
# 34번째 angular error = 4.5712
# 35번째 angular error = 1.7095
# 36번째 angular error = 3.6460
# 37번째 angular error = 3.3915
# 38번째 angular error = 3.7657
# 39번째 angular error = 3.8201
# 40번째 angular error = 2.1029
# 41번째 angular error = 1.5692
# 42번째 angular error = 2.9489
# 43번째 angular error = 4.1682
# 44번째 angular error = 1.9953
# 45번째 angular error = 2.1667
# 46번째 angular error = 7.9154
# 47번째 angular error = 1.3104
# 48번째 angular error = 17.0709
# 49번째 angular error = 23.7034
# 50번째 angular error = 1.1386
# 51번째 angular error = 3.7028
# 52번째 angular error = 5.3309
# 53번째 angular error = 23.0397
# 54번째 angular error = 3.3188
# 55번째 angular error = 2.6138
# 56번째 angular error = 22.1162
# 57번째 angular error = 16.8302
# 58번째 angular error = 3.6636
# 59번째 angular error = 1.5740
# 60번째 angular error = 1.8101
# 61번째 angular error = 19.5988
# 62번째 angular error = 4.1780
# 63번째 angular error = 23.0905
# 64번째 angular error = 3.7695
# 65번째 angular error = 0.6166
# 66번째 angular error = 19.0022
# 67번째 angular error = 3.2682
# 68번째 angular error = 1.8766
# 69번째 angular error = 14.7073
# 70번째 angular error = 1.5657
# 71번째 angular error = 1.7944
# 72번째 angular error = 4.3428
# 73번째 angular error = 3.6956
# 74번째 angular error = 2.3940
# 75번째 angular error = 14.5218
# 76번째 angular error = 27.2393
# 77번째 angular error = 2.1690
# 78번째 angular error = 4.2925
# 79번째 angular error = 18.2674
# 80번째 angular error = 1.3162
# 81번째 angular error = 3.2688
# 82번째 angular error = 3.3841
# 83번째 angular error = 2.8981
# 84번째 angular error = 2.1329
# 85번째 angular error = 2.1131
# 86번째 angular error = 19.3927
# 87번째 angular error = 0.8865
# 88번째 angular error = 4.7211
# 89번째 angular error = 3.0613
# 90번째 angular error = 2.9337
# 91번째 angular error = 3.0577
# 92번째 angular error = 5.2007
# 93번째 angular error = 4.5178
# 94번째 angular error = 2.0615
# 95번째 angular error = 3.9807
# 96번째 angular error = 3.3643
# 97번째 angular error = 18.4968
# 98번째 angular error = 3.1853
# 99번째 angular error = 1.2187
# 100번째 angular error = 4.6578
# 101번째 angular error = 2.6507
# 102번째 angular error = 1.3603
# 103번째 angular error = 22.4122
# 104번째 angular error = 2.9493
# 105번째 angular error = 1.9817
# 106번째 angular error = 3.9049
# 107번째 angular error = 6.5825
# 108번째 angular error = 2.2040
# 109번째 angular error = 2.8032
# 110번째 angular error = 3.7052
# 111번째 angular error = 1.0720
# 112번째 angular error = 6.6670
# 113번째 angular error = 6.9846
# 114번째 angular error = 3.0725
# 115번째 angular error = 2.3179
# 116번째 angular error = 2.5754
# 117번째 angular error = 21.8603
# 118번째 angular error = 3.7249
# 119번째 angular error = 6.6624
# 120번째 angular error = 19.1789
# 121번째 angular error = 3.1176
# 122번째 angular error = 2.1822
# 123번째 angular error = 8.7200
# 124번째 angular error = 2.3653
# 125번째 angular error = 1.5803
# 126번째 angular error = 7.3380
# 127번째 angular error = 6.0618
# 128번째 angular error = 6.7233
# 129번째 angular error = 15.0011
# 130번째 angular error = 2.8829
# 131번째 angular error = 10.4752
# 132번째 angular error = 3.6999
# 133번째 angular error = 2.2863
# 134번째 angular error = 2.2691
# 135번째 angular error = 3.5503
# 136번째 angular error = 3.6779
# 137번째 angular error = 4.0363
# 138번째 angular error = 5.4067
# 139번째 angular error = 5.9629
# 335번째 angular error = 21.9553
# 336번째 angular error = 4.2569
# 337번째 angular error = 22.6606
# 338번째 angular error = 4.8410
# 339번째 angular error = 4.3078
# 340번째 angular error = 19.7019
# 341번째 angular error = 7.1279
# 342번째 angular error = 2.7523
# 343번째 angular error = 1.7008
# 344번째 angular error = 14.0872
# 345번째 angular error = 1.8604
# 346번째 angular error = 1.9730
# 347번째 angular error = 2.7274
# 348번째 angular error = 23.3966
# 349번째 angular error = 3.7331
# 350번째 angular error = 2.4915
# 351번째 angular error = 1.6311
# 352번째 angular error = 1.5029
# 353번째 angular error = 3.7172
# 354번째 angular error = 3.7832
# 355번째 angular error = 5.4761
# 356번째 angular error = 3.9525
# 357번째 angular error = 0.8109
# 358번째 angular error = 1.8320
# 359번째 angular error = 6.7807
# 360번째 angular error = 1.3319
# 361번째 angular error = 1.4041
# 362번째 angular error = 3.0102
# 363번째 angular error = 2.7105
# 364번째 angular error = 2.4152
# 365번째 angular error = 2.5413
# 366번째 angular error = 2.0222
# 367번째 angular error = 21.9957
# 368번째 angular error = 0.9342
# 369번째 angular error = 2.2373
# 370번째 angular error = 19.5785
# 371번째 angular error = 8.3485
# 372번째 angular error = 2.0498
# 373번째 angular error = 1.9929
# 374번째 angular error = 1.6667
# 375번째 angular error = 1.8815
# 376번째 angular error = 0.3022
# 377번째 angular error = 5.3873
# 378번째 angular error = 1.1225
# 379번째 angular error = 1.6081
# 380번째 angular error = 1.1382
# 381번째 angular error = 1.1621
# 382번째 angular error = 16.2661
# 383번째 angular error = 1.3611
# 384번째 angular error = 1.8962
# 385번째 angular error = 2.6159
# 386번째 angular error = 12.3736
# 387번째 angular error = 25.4792
# 388번째 angular error = 4.3016
# 389번째 angular error = 25.4332
# 390번째 angular error = 9.6438
# 391번째 angular error = 2.9196
# 392번째 angular error = 3.4639
# 393번째 angular error = 7.0368
# 394번째 angular error = 29.1027
# 395번째 angular error = 0.9580
# 396번째 angular error = 1.9932
# 397번째 angular error = 3.1618
# 398번째 angular error = 2.2170
# 399번째 angular error = 3.8767
# 400번째 angular error = 26.2364
# 401번째 angular error = 18.3481
# 402번째 angular error = 1.6696
# 403번째 angular error = 9.3532
# 404번째 angular error = 2.5824
# 405번째 angular error = 3.6819
# 406번째 angular error = 1.8303
# 407번째 angular error = 3.5495
# 408번째 angular error = 3.7166
# 409번째 angular error = 8.4957
# 410번째 angular error = 30.0441
# 411번째 angular error = 2.2933
# 412번째 angular error = 2.3013
# 413번째 angular error = 3.7913
# 414번째 angular error = 14.6942
# 415번째 angular error = 1.3625
# 416번째 angular error = 2.5670
# 417번째 angular error = 6.5032
# 418번째 angular error = 1.1454
# 419번째 angular error = 3.1824
# 420번째 angular error = 3.0737
# 421번째 angular error = 3.4588
# 422번째 angular error = 2.5786
# 423번째 angular error = 6.4298
# 424번째 angular error = 14.4055
# 425번째 angular error = 24.3823
# 426번째 angular error = 1.0568
# 427번째 angular error = 9.7627
# 428번째 angular error = 5.5574
# 429번째 angular error = 2.6941
# 430번째 angular error = 21.8601
# 431번째 angular error = 9.6877
# 432번째 angular error = 0.3752
# 433번째 angular error = 2.5377
# 434번째 angular error = 22.0039
# 435번째 angular error = 3.3773
# 436번째 angular error = 2.3254
# 437번째 angular error = 11.8660
# 438번째 angular error = 2.2307
# 439번째 angular error = 7.3341
# 440번째 angular error = 1.5747
# 441번째 angular error = 4.6774
# 442번째 angular error = 2.5907
# 443번째 angular error = 2.2971
# 444번째 angular error = 3.3504
# 445번째 angular error = 4.1828
# 446번째 angular error = 3.3712
# 447번째 angular error = 3.6511
# 448번째 angular error = 3.9286
# 449번째 angular error = 5.8232
# 450번째 angular error = 3.2175
# 451번째 angular error = 4.7791
# 452번째 angular error = 1.7043
# 453번째 angular error = 2.3879
# 454번째 angular error = 3.1073
# 455번째 angular error = 6.4939
# 456번째 angular error = 4.8155
# 457번째 angular error = 25.7717
# 458번째 angular error = 2.3570
# 459번째 angular error = 3.8529
# 460번째 angular error = 3.6667
# 461번째 angular error = 4.0127
# 462번째 angular error = 3.4069
# 463번째 angular error = 2.7582
# 464번째 angular error = 18.5835
# 465번째 angular error = 5.4642
# 466번째 angular error = 3.5620
# 467번째 angular error = 6.0948
# 468번째 angular error = 18.1494
# 469번째 angular error = 3.4117
# 470번째 angular error = 17.7928
# 471번째 angular error = 3.7327
# 472번째 angular error = 2.7859
# 473번째 angular error = 3.5725
# 474번째 angular error = 24.9934
# 475번째 angular error = 1.3847
# 476번째 angular error = 3.6215
# 477번째 angular error = 6.9635
# 478번째 angular error = 25.2302
# 479번째 angular error = 6.5716
# 480번째 angular error = 5.2630
# 481번째 angular error = 3.3291
# 482번째 angular error = 6.3476
# 483번째 angular error = 1.9202
# 484번째 angular error = 4.3939
# 485번째 angular error = 3.1533
# 486번째 angular error = 2.4520
# 487번째 angular error = 24.4751
# 488번째 angular error = 4.1944
# 489번째 angular error = 6.6595
# 490번째 angular error = 1.7515
# 491번째 angular error = 8.4928
# 492번째 angular error = 5.6514
# 493번째 angular error = 6.3313
# 494번째 angular error = 3.2054
# 495번째 angular error = 4.0572
# 496번째 angular error = 4.3293
# 497번째 angular error = 3.8519
# 498번째 angular error = 13.5323
# 499번째 angular error = 2.5526
# 500번째 angular error = 2.7517
# 501번째 angular error = 2.2756
# 502번째 angular error = 1.8104
# 503번째 angular error = 2.5958
# 504번째 angular error = 23.9329
# 505번째 angular error = 3.7229
# 506번째 angular error = 4.1251
# 507번째 angular error = 13.7910
# 508번째 angular error = 27.5585
# 509번째 angular error = 11.8354
# 510번째 angular error = 7.3698
# 511번째 angular error = 4.4894
# 512번째 angular error = 4.6448
# 513번째 angular error = 0.9670
# 514번째 angular error = 25.8061
# 515번째 angular error = 3.5624
# 516번째 angular error = 2.4471
# 517번째 angular error = 5.1709
# 518번째 angular error = 5.0853
# 519번째 angular error = 6.5489
# 520번째 angular error = 3.1913
# 521번째 angular error = 3.3661
# 522번째 angular error = 3.5266
# 523번째 angular error = 21.3773
# 524번째 angular error = 7.4343
# 525번째 angular error = 24.8486
# 526번째 angular error = 3.6998
# 527번째 angular error = 6.8788
# 528번째 angular error = 6.3960
# 529번째 angular error = 26.4485
# 530번째 angular error = 3.1135
# 531번째 angular error = 3.2559
# 532번째 angular error = 9.2317
# 533번째 angular error = 4.2432
# 534번째 angular error = 1.3457
# 535번째 angular error = 2.2841
# 536번째 angular error = 4.6238
# 537번째 angular error = 3.5203
# 538번째 angular error = 3.8867
# 539번째 angular error = 9.6139
# 540번째 angular error = 1.1070
# 541번째 angular error = 12.3339
# 542번째 angular error = 3.7253
# 543번째 angular error = 3.4358
# 544번째 angular error = 1.6072
# 545번째 angular error = 2.3572
# 546번째 angular error = 24.2872
# 547번째 angular error = 24.7103
# 548번째 angular error = 10.4854
# 549번째 angular error = 9.6629
# 550번째 angular error = 1.9280
# 551번째 angular error = 3.5545
# 552번째 angular error = 3.8012
# 553번째 angular error = 3.3201
# 554번째 angular error = 24.5514
# 555번째 angular error = 3.8066
# 556번째 angular error = 19.9330
# 557번째 angular error = 3.4002
# 558번째 angular error = 21.0023
# 559번째 angular error = 3.0849
# 560번째 angular error = 3.5682
# 561번째 angular error = 13.5429
# 562번째 angular error = 5.6268
# 563번째 angular error = 21.2566
# 564번째 angular error = 1.8912
# 565번째 angular error = 1.7855
# 566번째 angular error = 1.2838
# 567번째 angular error = 3.5545
# 568번째 angular error = 3.7799
# 569번째 angular error = 19.6021
# 570번째 angular error = 2.8302
# 571번째 angular error = 21.6993
# 572번째 angular error = 8.3069
# 573번째 angular error = 23.2552
# 574번째 angular error = 18.7703
# 575번째 angular error = 20.0500
# 576번째 angular error = 22.5903
# 577번째 angular error = 3.2632
# average:6.8241 | median:3.9049 | worst:17.0430 | Best:1.7769
# ===> Processing Done
# ===> Epoch[6](1/145): Loss: 11.3907 || Timer: 0.0083 sec.
# ===> Epoch[6](2/145): Loss: 7.1074 || Timer: 0.0034 sec.
# ===> Epoch[6](3/145): Loss: 4.4737 || Timer: 0.0037 sec.
# ===> Epoch[6](4/145): Loss: 5.9019 || Timer: 0.0041 sec.
# ===> Epoch[6](5/145): Loss: 6.1278 || Timer: 0.0033 sec.
# ===> Epoch[6](6/145): Loss: 7.1615 || Timer: 0.0037 sec.
# ===> Epoch[6](7/145): Loss: 7.9953 || Timer: 0.0041 sec.
# ===> Epoch[6](8/145): Loss: 8.2761 || Timer: 0.0040 sec.
# ===> Epoch[6](9/145): Loss: 4.3901 || Timer: 0.0039 sec.
# ===> Epoch[6](10/145): Loss: 6.9402 || Timer: 0.0045 sec.
# ===> Epoch[6](11/145): Loss: 5.7550 || Timer: 0.0038 sec.
# ===> Epoch[6](12/145): Loss: 6.2006 || Timer: 0.0046 sec.
# ===> Epoch[6](13/145): Loss: 4.5184 || Timer: 0.0032 sec.
# ===> Epoch[6](14/145): Loss: 10.7965 || Timer: 0.0040 sec.
# ===> Epoch[6](15/145): Loss: 8.8685 || Timer: 0.0041 sec.
# ===> Epoch[6](16/145): Loss: 8.1690 || Timer: 0.0032 sec.
# ===> Epoch[6](17/145): Loss: 4.7440 || Timer: 0.0033 sec.
# ===> Epoch[6](18/145): Loss: 6.5318 || Timer: 0.0031 sec.
# ===> Epoch[6](19/145): Loss: 7.1891 || Timer: 0.0056 sec.
# ===> Epoch[6](20/145): Loss: 7.5941 || Timer: 0.0086 sec.
# ===> Epoch[6](21/145): Loss: 5.0561 || Timer: 0.0049 sec.
# ===> Epoch[6](22/145): Loss: 9.7808 || Timer: 0.0188 sec.
# ===> Epoch[6](23/145): Loss: 15.6965 || Timer: 0.0104 sec.
# ===> Epoch[6](24/145): Loss: 8.3594 || Timer: 0.0048 sec.
# ===> Epoch[6](25/145): Loss: 6.8671 || Timer: 0.0125 sec.
# ===> Epoch[6](26/145): Loss: 4.6701 || Timer: 0.0073 sec.
# ===> Epoch[6](27/145): Loss: 3.6695 || Timer: 0.0047 sec.
# ===> Epoch[6](28/145): Loss: 5.6377 || Timer: 0.0105 sec.
# ===> Epoch[6](29/145): Loss: 9.0380 || Timer: 0.0083 sec.
# ===> Epoch[6](30/145): Loss: 5.9064 || Timer: 0.0032 sec.
# ===> Epoch[6](31/145): Loss: 5.9138 || Timer: 0.0252 sec.
# ===> Epoch[6](32/145): Loss: 9.1990 || Timer: 0.0032 sec.
# ===> Epoch[6](33/145): Loss: 3.1720 || Timer: 0.0035 sec.
# ===> Epoch[6](34/145): Loss: 6.1261 || Timer: 0.0119 sec.
# ===> Epoch[6](35/145): Loss: 8.3217 || Timer: 0.0033 sec.
# ===> Epoch[6](36/145): Loss: 5.4564 || Timer: 0.0039 sec.
# ===> Epoch[6](37/145): Loss: 4.9265 || Timer: 0.0047 sec.
# ===> Epoch[6](38/145): Loss: 6.5460 || Timer: 0.0100 sec.
# ===> Epoch[6](39/145): Loss: 5.3902 || Timer: 0.0050 sec.
# ...
# 31번째 angular error = 5.1056
# 32번째 angular error = 11.8567
# 33번째 angular error = 9.9697
# 34번째 angular error = 5.3742
# 35번째 angular error = 2.4472
# 36번째 angular error = 2.9564
# 37번째 angular error = 3.0072
# 38번째 angular error = 4.5776
# 39번째 angular error = 3.2217
# 40번째 angular error = 2.8720
# 41번째 angular error = 0.8488
# 42번째 angular error = 3.7756
# 43번째 angular error = 3.5403
# 44번째 angular error = 2.8036
# 45번째 angular error = 2.7363
# 46번째 angular error = 8.4834
# 47번째 angular error = 1.0720
# 48번째 angular error = 16.4903
# 49번째 angular error = 23.1994
# 50번째 angular error = 1.8781
# 51번째 angular error = 4.2204
# 52번째 angular error = 6.1159
# 53번째 angular error = 22.5741
# 54번째 angular error = 3.8764
# 55번째 angular error = 3.3258
# 56번째 angular error = 21.5853
# 57번째 angular error = 16.3267
# 58번째 angular error = 4.2429
# 59번째 angular error = 0.9985
# 60번째 angular error = 2.5040
# 61번째 angular error = 19.0535
# 62번째 angular error = 3.4887
# 63번째 angular error = 22.6047
# 64번째 angular error = 4.3980
# 65번째 angular error = 0.7400
# 66번째 angular error = 18.4627
# 67번째 angular error = 3.9227
# 68번째 angular error = 1.0319
# 69번째 angular error = 14.1937
# 70번째 angular error = 1.9032
# 71번째 angular error = 2.2566
# 72번째 angular error = 4.8698
# 73번째 angular error = 4.5245
# 74번째 angular error = 1.7922
# 75번째 angular error = 13.9764
# 76번째 angular error = 26.7774
# 77번째 angular error = 2.6999
# 78번째 angular error = 3.7373
# 79번째 angular error = 17.6564
# 80번째 angular error = 1.9762
# 81번째 angular error = 3.8066
# 82번째 angular error = 4.2078
# 83번째 angular error = 3.5884
# 84번째 angular error = 2.6524
# 85번째 angular error = 2.8380
# 86번째 angular error = 18.7466
# 87번째 angular error = 1.5553
# 88번째 angular error = 4.0608
# 89번째 angular error = 3.6374
# 90번째 angular error = 3.4198
# 91번째 angular error = 3.4928
# 92번째 angular error = 4.4501
# 93번째 angular error = 3.8022
# 94번째 angular error = 2.7653
# 95번째 angular error = 4.6002
# 96번째 angular error = 2.7046
# 97번째 angular error = 18.0221
# 98번째 angular error = 2.5199
# 99번째 angular error = 1.9383
# 100번째 angular error = 3.9837
# 101번째 angular error = 3.0843
# 102번째 angular error = 2.1186
# 103번째 angular error = 21.8393
# 104번째 angular error = 2.2544
# 105번째 angular error = 1.4794
# 106번째 angular error = 4.5321
# 107번째 angular error = 5.9124
# 108번째 angular error = 2.9049
# 109번째 angular error = 3.4943
# 110번째 angular error = 3.0842
# 111번째 angular error = 1.7951
# 112번째 angular error = 7.2871
# 113번째 angular error = 6.3006
# 114번째 angular error = 3.7350
# 115번째 angular error = 2.9811
# 116번째 angular error = 3.1716
# 117번째 angular error = 21.2375
# 118번째 angular error = 4.3860
# 119번째 angular error = 5.9677
# 120번째 angular error = 18.6267
# 121번째 angular error = 3.5150
# 122번째 angular error = 2.9263
# 123번째 angular error = 7.9675
# 124번째 angular error = 1.5215
# 125번째 angular error = 1.6134
# 126번째 angular error = 6.5860
# 127번째 angular error = 5.3595
# 128번째 angular error = 7.3263
# 129번째 angular error = 14.3019
# 130번째 angular error = 2.9402
# 131번째 angular error = 9.8086
# 132번째 angular error = 4.1338
# 133번째 angular error = 2.2293
# 134번째 angular error = 2.8256
# 135번째 angular error = 3.9988
# 136번째 angular error = 4.0898
# 137번째 angular error = 4.5285
# 138번째 angular error = 5.9058
# 139번째 angular error = 6.4978
# 140번째 angular error = 21.2808
# 141번째 angular error = 3.6795
# 142번째 angular error = 2.0711
# 143번째 angular error = 8.2219
# 144번째 angular error = 2.7319
# 145번째 angular error = 5.7146
# 146번째 angular error = 23.4359
# 147번째 angular error = 2.0493
# 148번째 angular error = 3.1522
# 149번째 angular error = 27.1230
# 150번째 angular error = 3.9192
# 151번째 angular error = 17.3024
# 152번째 angular error = 3.6765
# 153번째 angular error = 3.1077
# 154번째 angular error = 6.0673
# 155번째 angular error = 1.2412
# 156번째 angular error = 2.3197
# 157번째 angular error = 1.5850
# 158번째 angular error = 1.4192
# 159번째 angular error = 0.9115
# 160번째 angular error = 2.2728
# 161번째 angular error = 2.3754
# 162번째 angular error = 2.8009
# 163번째 angular error = 1.9864
# 164번째 angular error = 19.3172
# 165번째 angular error = 1.8916
# 166번째 angular error = 7.6640
# 167번째 angular error = 12.7239
# 168번째 angular error = 3.7144
# 169번째 angular error = 4.1041
# 170번째 angular error = 2.5724
# 171번째 angular error = 2.7482
# 172번째 angular error = 25.5469
# 173번째 angular error = 6.9839
# 174번째 angular error = 4.4205
# 175번째 angular error = 16.6504
# 176번째 angular error = 18.8597
# 177번째 angular error = 1.9295
# 178번째 angular error = 1.5795
# 179번째 angular error = 2.9632
# 180번째 angular error = 19.2280
# 181번째 angular error = 7.4793
# 182번째 angular error = 3.9717
# 183번째 angular error = 1.0837
# 184번째 angular error = 2.4555
# 185번째 angular error = 2.3014
# 186번째 angular error = 3.1683
# 187번째 angular error = 18.3117
# 188번째 angular error = 1.9679
# 189번째 angular error = 1.7096
# 190번째 angular error = 2.8672
# 191번째 angular error = 7.9594
# 192번째 angular error = 4.2482
# 193번째 angular error = 1.8297
# 194번째 angular error = 5.3540
# 195번째 angular error = 2.3159
# 196번째 angular error = 9.4660
# 197번째 angular error = 5.6880
# 198번째 angular error = 3.6982
# 199번째 angular error = 1.5856
# 200번째 angular error = 7.9975
# 201번째 angular error = 4.7058
# 202번째 angular error = 4.1216
# 203번째 angular error = 5.6358
# 204번째 angular error = 5.5228
# 205번째 angular error = 5.5371
# 206번째 angular error = 10.2257
# 207번째 angular error = 5.2109
# 208번째 angular error = 8.5456
# 209번째 angular error = 4.5880
# 210번째 angular error = 7.2404
# 211번째 angular error = 5.7539
# 212번째 angular error = 5.2749
# 213번째 angular error = 4.1842
# 214번째 angular error = 4.3085
# 215번째 angular error = 2.2458
# 216번째 angular error = 1.1777
# 217번째 angular error = 2.4808
# 218번째 angular error = 5.6523
# 219번째 angular error = 5.0053
# 220번째 angular error = 5.2606
# 221번째 angular error = 4.2842
# 222번째 angular error = 5.1525
# 223번째 angular error = 6.5624
# 224번째 angular error = 4.0041
# 225번째 angular error = 5.2299
# 226번째 angular error = 5.4302
# 227번째 angular error = 7.2212
# 228번째 angular error = 3.1473
# 229번째 angular error = 7.3697
# 230번째 angular error = 3.2971
# 231번째 angular error = 2.1133
# 232번째 angular error = 1.8325
# 233번째 angular error = 9.6949
# 234번째 angular error = 4.1499
# 235번째 angular error = 5.6929
# 236번째 angular error = 6.4407
# 237번째 angular error = 4.8762
# 238번째 angular error = 4.5053
# 239번째 angular error = 4.6713
# 240번째 angular error = 6.0899
# 241번째 angular error = 5.6132
# 242번째 angular error = 9.4974
# 243번째 angular error = 5.4536
# 244번째 angular error = 1.8216
# 245번째 angular error = 8.3578
# 246번째 angular error = 7.2263
# 247번째 angular error = 25.2765
# 248번째 angular error = 11.3490
# 249번째 angular error = 5.7448
# 250번째 angular error = 5.4763
# 251번째 angular error = 6.3574
# 252번째 angular error = 6.2158
# 253번째 angular error = 2.3104
# 254번째 angular error = 6.3176
# 255번째 angular error = 16.2204
# 256번째 angular error = 18.8903
# 257번째 angular error = 4.7895
# 258번째 angular error = 2.9452
# 259번째 angular error = 19.0588
# 260번째 angular error = 2.8001
# 261번째 angular error = 3.6525
# 262번째 angular error = 7.8646
# 263번째 angular error = 5.1392
# 264번째 angular error = 5.9149
# 265번째 angular error = 4.8571
# 266번째 angular error = 5.6336
# 267번째 angular error = 14.8988
# 268번째 angular error = 6.5196
# 269번째 angular error = 6.8309
# 270번째 angular error = 6.6340
# 271번째 angular error = 22.1813
# 272번째 angular error = 4.7963
# 273번째 angular error = 4.9062
# 274번째 angular error = 14.3192
# 275번째 angular error = 5.0192
# 276번째 angular error = 3.1101
# 277번째 angular error = 6.4269
# 278번째 angular error = 9.5408
# 279번째 angular error = 14.8948
# 280번째 angular error = 5.4280
# 281번째 angular error = 7.0415
# 282번째 angular error = 3.2926
# 283번째 angular error = 18.7751
# 284번째 angular error = 9.0708
# 285번째 angular error = 5.1870
# 286번째 angular error = 14.9037
# 287번째 angular error = 4.4475
# 288번째 angular error = 1.6623
# 289번째 angular error = 5.3479
# 290번째 angular error = 11.9793
# 291번째 angular error = 22.2640
# 292번째 angular error = 4.3422
# 293번째 angular error = 5.5518
# 294번째 angular error = 4.4497
# 295번째 angular error = 6.5006
# 296번째 angular error = 5.4867
# 297번째 angular error = 4.4056
# 298번째 angular error = 2.4329
# 299번째 angular error = 14.8689
# 300번째 angular error = 10.5377
# 301번째 angular error = 4.7504
# 302번째 angular error = 19.8353
# 303번째 angular error = 4.3706
# 304번째 angular error = 4.0977
# 305번째 angular error = 3.7566
# 306번째 angular error = 14.3508
# 307번째 angular error = 3.9861
# 308번째 angular error = 1.5496
# 309번째 angular error = 18.8701
# 310번째 angular error = 3.5510
# 311번째 angular error = 22.0666
# 312번째 angular error = 4.4660
# 313번째 angular error = 5.3493
# 314번째 angular error = 4.1441
# 315번째 angular error = 1.6606
# 316번째 angular error = 5.1062
# 317번째 angular error = 3.7638
# 318번째 angular error = 3.3191
# 319번째 angular error = 3.5977
# 320번째 angular error = 2.9562
# 321번째 angular error = 3.0072
# 322번째 angular error = 5.6477
# 323번째 angular error = 4.0164
# 324번째 angular error = 6.7795
# 325번째 angular error = 18.9628
# 326번째 angular error = 14.9366
# 327번째 angular error = 6.7370
# 328번째 angular error = 3.2628
# 329번째 angular error = 4.8593
# 330번째 angular error = 5.8001
# 331번째 angular error = 3.4623
# 332번째 angular error = 2.1301
# 333번째 angular error = 2.5084
# 334번째 angular error = 1.8782
# 335번째 angular error = 21.4070
# 336번째 angular error = 5.0146
# 337번째 angular error = 22.1042
# 338번째 angular error = 4.2938
# 339번째 angular error = 5.1137
# 340번째 angular error = 19.1782
# 341번째 angular error = 6.5288
# 342번째 angular error = 3.5554
# 343번째 angular error = 2.4606
# 344번째 angular error = 13.4519
# 345번째 angular error = 2.6598
# 346번째 angular error = 1.6537
# 347번째 angular error = 1.9316
# 348번째 angular error = 22.9646
# 349번째 angular error = 3.3030
# 350번째 angular error = 3.2848
# 351번째 angular error = 1.1004
# 352번째 angular error = 2.3421
# 353번째 angular error = 4.5263
# 354번째 angular error = 4.5885
# 355번째 angular error = 6.2371
# 356번째 angular error = 3.4769
# 357번째 angular error = 1.3980
# 358번째 angular error = 2.6033
# 359번째 angular error = 7.5523
# 360번째 angular error = 1.0850
# 361번째 angular error = 1.4343
# 362번째 angular error = 3.7883
# 363번째 angular error = 3.5382
# 364번째 angular error = 3.1862
# 365번째 angular error = 3.3095
# 366번째 angular error = 2.7889
# 367번째 angular error = 21.3940
# 368번째 angular error = 1.6578
# 369번째 angular error = 2.3670
# 370번째 angular error = 19.0794
# 371번째 angular error = 7.7253
# 372번째 angular error = 2.8149
# 373번째 angular error = 2.7481
# 374번째 angular error = 2.4659
# 375번째 angular error = 1.7944
# 376번째 angular error = 0.9260
# 377번째 angular error = 4.9246
# 378번째 angular error = 1.9271
# 379번째 angular error = 1.4620
# 380번째 angular error = 1.7537
# 381번째 angular error = 1.0266
# 382번째 angular error = 15.7473
# 383번째 angular error = 2.1225
# 384번째 angular error = 2.6892
# 385번째 angular error = 3.4102
# 386번째 angular error = 11.8582
# 387번째 angular error = 25.0507
# 388번째 angular error = 5.0763
# 389번째 angular error = 25.0190
# 390번째 angular error = 9.0523
# 391번째 angular error = 3.7012
# 392번째 angular error = 3.1218
# 393번째 angular error = 6.6093
# 394번째 angular error = 28.6634
# 395번째 angular error = 1.0151
# 396번째 angular error = 2.7488
# 397번째 angular error = 3.9749
# 398번째 angular error = 2.0137
# 399번째 angular error = 3.4393
# 400번째 angular error = 25.7095
# 401번째 angular error = 17.7876
# 402번째 angular error = 2.4775
# 403번째 angular error = 8.8441
# 404번째 angular error = 2.0764
# 405번째 angular error = 3.3765
# 406번째 angular error = 2.6324
# 407번째 angular error = 3.2026
# 408번째 angular error = 2.9572
# 409번째 angular error = 7.8271
# 410번째 angular error = 29.6317
# 411번째 angular error = 3.1044
# 412번째 angular error = 2.2145
# 413번째 angular error = 3.2380
# 414번째 angular error = 14.0177
# 415번째 angular error = 2.0885
# 416번째 angular error = 2.2259
# 417번째 angular error = 6.0226
# 418번째 angular error = 1.9257
# 419번째 angular error = 3.9851
# 420번째 angular error = 2.4650
# 421번째 angular error = 2.6814
# 422번째 angular error = 3.3626
# 423번째 angular error = 6.0082
# 424번째 angular error = 13.7565
# 425번째 angular error = 23.9734
# 426번째 angular error = 1.8020
# 427번째 angular error = 9.1920
# 428번째 angular error = 4.8856
# 429번째 angular error = 2.5681
# 430번째 angular error = 21.2811
# 431번째 angular error = 9.3169
# 432번째 angular error = 1.0310
# 433번째 angular error = 2.2219
# 434번째 angular error = 21.4114
# 435번째 angular error = 2.8035
# 436번째 angular error = 2.1690
# 437번째 angular error = 11.3261
# 438번째 angular error = 1.9979
# 439번째 angular error = 8.0690
# 440번째 angular error = 2.1460
# 441번째 angular error = 4.1606
# 442번째 angular error = 2.3227
# 443번째 angular error = 1.7926
# 444번째 angular error = 3.5771
# 445번째 angular error = 3.7809
# 446번째 angular error = 3.0597
# 447번째 angular error = 2.9191
# 448번째 angular error = 4.4036
# 449번째 angular error = 5.9286
# 450번째 angular error = 2.9689
# 451번째 angular error = 5.3141
# 452번째 angular error = 1.5205
# 453번째 angular error = 2.5352
# 454번째 angular error = 3.5565
# 455번째 angular error = 5.8013
# 456번째 angular error = 4.4115
# 457번째 angular error = 25.2137
# 458번째 angular error = 1.5885
# 459번째 angular error = 3.5338
# 460번째 angular error = 4.0321
# 461번째 angular error = 4.4816
# 462번째 angular error = 3.5219
# 463번째 angular error = 1.9280
# 464번째 angular error = 18.1540
# 465번째 angular error = 5.8474
# 466번째 angular error = 3.8873
# 467번째 angular error = 6.3763
# 468번째 angular error = 17.6159
# 469번째 angular error = 3.5378
# 470번째 angular error = 17.2422
# 471번째 angular error = 3.6105
# 472번째 angular error = 2.9501
# 473번째 angular error = 3.9533
# 474번째 angular error = 24.4826
# 475번째 angular error = 1.8525
# 476번째 angular error = 3.8969
# 477번째 angular error = 6.1299
# 478번째 angular error = 24.7145
# 479번째 angular error = 7.0430
# 480번째 angular error = 5.7818
# 481번째 angular error = 2.9442
# 482번째 angular error = 6.8807
# 483번째 angular error = 1.9407
# 484번째 angular error = 4.0753
# 485번째 angular error = 2.6205
# 486번째 angular error = 2.2518
# 487번째 angular error = 23.9882
# 488번째 angular error = 4.6330
# 489번째 angular error = 5.9137
# 490번째 angular error = 2.5885
# 491번째 angular error = 7.9584
# 492번째 angular error = 6.1636
# 493번째 angular error = 5.5428
# 494번째 angular error = 3.5178
# 495번째 angular error = 3.2687
# 496번째 angular error = 3.5544
# 497번째 angular error = 3.5722
# 498번째 angular error = 12.8023
# 499번째 angular error = 2.3670
# 500번째 angular error = 2.4303
# 501번째 angular error = 2.1048
# 502번째 angular error = 1.2820
# 503번째 angular error = 2.6233
# 504번째 angular error = 23.3322
# 505번째 angular error = 3.1471
# 506번째 angular error = 3.5503
# 507번째 angular error = 13.2852
# 508번째 angular error = 27.0466
# 509번째 angular error = 11.2109
# 510번째 angular error = 6.5834
# 511번째 angular error = 4.9689
# 512번째 angular error = 4.9289
# 513번째 angular error = 1.4835
# 514번째 angular error = 25.2509
# 515번째 angular error = 2.8450
# 516번째 angular error = 2.5030
# 517번째 angular error = 4.5521
# 518번째 angular error = 5.6023
# 519번째 angular error = 7.0823
# 520번째 angular error = 3.5676
# 521번째 angular error = 2.6433
# 522번째 angular error = 3.8272
# 523번째 angular error = 20.7856
# 524번째 angular error = 6.8615
# 525번째 angular error = 24.2791
# 526번째 angular error = 3.1817
# 527번째 angular error = 6.2746
# 528번째 angular error = 5.7952
# 529번째 angular error = 25.8858
# 530번째 angular error = 3.4727
# 531번째 angular error = 3.3413
# 532번째 angular error = 8.6815
# 533번째 angular error = 4.7696
# 534번째 angular error = 1.6948
# 535번째 angular error = 2.3176
# 536번째 angular error = 3.8188
# 537번째 angular error = 3.7438
# 538번째 angular error = 4.2055
# 539번째 angular error = 9.0012
# 540번째 angular error = 0.4660
# 541번째 angular error = 11.5678
# 542번째 angular error = 4.0733
# 543번째 angular error = 2.7594
# 544번째 angular error = 1.3110
# 545번째 angular error = 1.7184
# 546번째 angular error = 23.7826
# 547번째 angular error = 24.1007
# 548번째 angular error = 9.7476
# 549번째 angular error = 8.9214
# 550번째 angular error = 1.9326
# 551번째 angular error = 2.9251
# 552번째 angular error = 3.2165
# 553번째 angular error = 3.7450
# 554번째 angular error = 24.0426
# 555번째 angular error = 3.1842
# 556번째 angular error = 19.3183
# 557번째 angular error = 2.7614
# 558번째 angular error = 20.3593
# 559번째 angular error = 2.3044
# 560번째 angular error = 3.9931
# 561번째 angular error = 12.9435
# 562번째 angular error = 4.9618
# 563번째 angular error = 20.7026
# 564번째 angular error = 1.8320
# 565번째 angular error = 1.1094
# 566번째 angular error = 0.6730
# 567번째 angular error = 3.0409
# 568번째 angular error = 3.1364
# 569번째 angular error = 18.9935
# 570번째 angular error = 3.1477
# 571번째 angular error = 21.1422
# 572번째 angular error = 7.6371
# 573번째 angular error = 22.6754
# 574번째 angular error = 18.1845
# 575번째 angular error = 19.4097
# 576번째 angular error = 21.9848
# 577번째 angular error = 2.6219
# average:6.8376 | median:4.1436 | worst:16.5954 | Best:1.9537
# ===> Processing Done

# %% [markdown]
# #Test

# %%
from __future__ import print_function
import argparse

import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
from functools import reduce
from math import log10
import scipy.io as sio
import time
import cv2
import easydict
from google.colab import drive
drive.mount('/content/drive')

opt = easydict.EasyDict({
    "testBatchSize": 1,
    "self_ensemble": False,
    "chop_forward": False,
    "gpu_mode": True,
    "threads": 1,
    "seed": 123,
    "gpus": 1,
    "data_dir":"/content/drive/MyDrive/Colab Notebooks/dataset/",  # test dataset 불러올위치
    "output": "/content/drive/MyDrive/Colab Notebooks/results/", # 결과영상 저장위치
    "model_type": "FC4",
    "residual": False,
    "model": "/content/drive/MyDrive/Colab Notebooks/weight/epoch_1.pth"})  # test에 사용할 weight 불러올 위치 ac040091dff2_epoch_59.pth


device = "cuda"
print(opt)

cuda = opt.gpu_mode
if cuda and not torch.cuda.is_available():
    raise Exception("No GPU found, please run without --cuda")
if not os.path.exists(opt.output):
    os.makedirs(opt.output)

torch.manual_seed(opt.seed)




print('===> Loading datasets')
test_set = DatasetFromFolder(image_dir = opt.data_dir, folder = "test/" , isTrain = False, transform = transform())
testing_data_loader = DataLoader(dataset=test_set, num_workers=opt.threads, batch_size=opt.testBatchSize, shuffle=False)


print('===> Building model')

model = FC4(in_ch=3,out_ch=4)
model = torch.nn.DataParallel(model, device_ids= [0])
model.load_state_dict(torch.load(opt.model, map_location=lambda storage, loc: storage))
print('Pre-trained FC4 model is loaded.')

if cuda:
    model = model.cuda()


def angular_loss(pred, gt):
    pred.cuda()
    gt.cuda()
    a = (pred[:, 0] * gt[:, 0] + pred[:, 1] * gt[:, 1] + pred[:, 2] * gt[:, 2])
    b = pow(torch.abs(pred[:, 0] * pred[:, 0] + pred[:, 1] * pred[:, 1] + pred[:, 2] * pred[:, 2] + 1e-06), 1 / 2)
    c = pow(torch.abs(gt[:, 0] * gt[:, 0] + gt[:, 1] * gt[:, 1] + gt[:, 2] * gt[:, 2] + 1e-06), 1 / 2)

    acos = torch.acos(a / (b * c + 1e-05))
    output = torch.mean(acos)
    output = output * 180 / math.pi

    return output


def eval():
    excel_i=[]
    excel_cc=[]
    angular_list = []
    avg_cc = 0
    model.eval()

    for i,batch in enumerate(testing_data_loader):
        with torch.no_grad():
            rgb,wb_rgb,gt_label,file = Variable(batch[0]), Variable(batch[1]), Variable(batch[2]), batch[3]
        if cuda:
            rgb = rgb.cuda()
            wb_rgb = wb_rgb.cuda()
            gt_label = gt_label.cuda()

        with torch.no_grad():
            pred = model(rgb)


        t0 = time.time()

        cc_loss = angular_loss(pred, gt_label)
        avg_cc += cc_loss

        t1 = time.time()
        print(f'{i} 번째 angular error : {cc_loss}')
        angular_list.append(cc_loss)
    index_min = []
    index_max = []
    '''AE measure'''
    angular_list1 = angular_list[:]
    angular_list.sort()
    onefourth = len(testing_data_loader)//4

    median = angular_list[len(testing_data_loader)//2]
    maxerror,minerror = 0,0
    # min 25% error
    for i in range(onefourth):
        minerror += angular_list[i]
        index_min.append(angular_list1.index(angular_list[i]))
    # max 25% error
    angular_list.sort(reverse=True)
    for i in range(onefourth):
        maxerror += angular_list[i]
        index_max.append(angular_list1.index(angular_list[i]))

    maxerror = maxerror/onefourth
    minerror = minerror/onefourth
    avg_cc = avg_cc / len(testing_data_loader)
    print('median angular error = {}'.format(median))
    print('average angular error = {}'.format(avg_cc))
    print('max 25% angular error = {}'.format(maxerror))
    print('min 25% angular error = {}'.format(minerror))


def save_img(img, img_name):
    save_img = img.squeeze().clamp(0, 1).numpy().transpose(1,2,0)
    # save img
    save_dir=os.path.join(opt.output,opt.test_dataset)
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    save_fn = save_dir +'/'+ img_name
    cv2.imwrite(save_fn, cv2.cvtColor(save_img*255, cv2.COLOR_BGR2RGB),  [cv2.IMWRITE_PNG_COMPRESSION, 0])



##Eval Start!!!!
if __name__ == '__main__':
    eval()
# Out:
# {'testBatchSize': 1, 'self_ensemble': False, 'chop_forward': False, 'gpu_mode': True, 'threads': 1, 'seed': 123, 'gpus': 1, 'data_dir': '/content/drive/MyDrive/cc_dataset/dataset/', 'output': '/content/drive/MyDrive/result/cc/', 'model_type': 'FC4', 'residual': False, 'model': '/content/drive/MyDrive/weights/cc/epoch_10.pth'}
# ===> Loading datasets
# ===> Building model
# Pre-trained FC4 model is loaded.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3cbe98e7b794> in <cell line: 140>()
#     139 ##Eval Start!!!!
#     140 if __name__ == '__main__':
# --> 141     eval()
#
# <ipython-input-7-3cbe98e7b794> in eval()
#      76     angular_list = []
#      77     avg_cc = 0
# ---> 78     for i, batch in enumerate(testing_data_loader):
#      79         with torch.no_grad():
#      80             rgb, wb_rgb, gt_label = Variable(batch[0]), Variable(batch[1]), Variable(batch[2])
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     629                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630                 self._reset()  # type: ignore[call-arg]
# --> 631             data = self._next_data()
#     632             self._num_yielded += 1
#     633             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1327
#    1328             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1329             idx, data = self._get_data()
#    1330             self._tasks_outstanding -= 1
#    1331             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1293         else:
#    1294             while True:
# -> 1295                 success, data = self._try_get_data()
#    1296                 if success:
#    1297                     return data
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1131         #   (bool: whether successfully get data, any: data if successful else None)
#    1132         try:
# -> 1133             data = self._data_queue.get(timeout=timeout)
#    1134             return (True, data)
#    1135         except Exception as e:
#
# /usr/lib/python3.10/multiprocessing/queues.py in get(self, block, timeout)
#     111                 if block:
#     112                     timeout = deadline - time.monotonic()
# --> 113                     if not self._poll(timeout):
#     114                         raise Empty
#     115                 elif not self._poll():
#
# /usr/lib/python3.10/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /usr/lib/python3.10/multiprocessing/connection.py in _poll(self, timeout)
#     422
#     423     def _poll(self, timeout):
# --> 424         r = wait([self], timeout)
#     425         return bool(r)
#     426
#
# /usr/lib/python3.10/multiprocessing/connection.py in wait(object_list, timeout)
#     929
#     930             while True:
# --> 931                 ready = selector.select(timeout)
#     932                 if ready:
#     933                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.10/selectors.py in select(self, timeout)
#     414         ready = []
#     415         try:
# --> 416             fd_event_list = self._selector.poll(timeout)
#     417         except InterruptedError:
#     418             return ready
#
# KeyboardInterrupt:
